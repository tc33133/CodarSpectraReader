# %%
# %matplotlib notebook
import struct
import numpy as np
import matplotlib.pyplot as plt
import readCS 
import xarray as xr

# %% [markdown]
# ### This is a quick notebook about using readCS.py to read Codar CSS & CSQ files

# %%
#spectra_file="/Users/tom/Documents/work/Palau/ANGU/Spectra/2016_03_Mar/CSS_ANGU_16_03_10_0300.cs"
#spectra_file="/Users/tom/Documents/work/Palau/ANGU/Spectra/ANGU_CSQ_2016_03_10/CSQ_ANGU_16_03_10_055503.cs"
spectra_file="/Users/tom/Documents/work/Palau/ANGU/Spectra/ANGU_CSQ_2016_03_10/CSQ_ANGU_16_03_10_035539.cs"

# %% [markdown]
# ### Read the spectra with readCS.py

# %%
(A1spectra,A2spectra,A3spectra,A12spectra,A13spectra,A23spectra)=readCS.readCS(spectra_file)

# %% [markdown]
# ### designate range and doppler cells

# %%
rangeCells=range(0,A12spectra.shape[0])
dopplerCells=range(0,A12spectra.shape[1])

# %% [markdown]
# ### Plot the contents of CSS File<br>use readCS.datatoSS to plot log values

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
CB=plt.pcolormesh(readCS.datatoSS(A1spectra),cmap='jet')
plt.subplot(1,3,2)
plt.pcolormesh(readCS.datatoSS(A2spectra),cmap='jet')
plt.subplot(1,3,3)
plt.pcolormesh(readCS.datatoSS(A3spectra),cmap='jet')
plt.colorbar(CB)

plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
CB=plt.pcolormesh(readCS.datatoSS(A12spectra),cmap='jet')
plt.subplot(1,3,2)
plt.pcolormesh(readCS.datatoSS(A13spectra),cmap='jet')
plt.subplot(1,3,3)
plt.pcolormesh(readCS.datatoSS(A23spectra),cmap='jet')
plt.colorbar(CB)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">

# %%
plt.figure()
plt.plot(readCS.datatoSS(A1spectra[4,:]))
plt.plot(readCS.datatoSS(A2spectra[4,:]))
plt.plot(readCS.datatoSS(A3spectra[4,:]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
readCS.datatoSS(A12spectra[4,142])
# Out:
# -131.9449501386672
